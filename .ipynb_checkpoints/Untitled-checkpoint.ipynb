# %%
library(tidyverse)
library(tidymodels)
library(cowplot)
library(scales)
library(repr)
install.packages("plotly")
library(plotly)
# Out:
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout

# %%
players <- read_csv("https://drive.google.com/uc?export=download&id=1Mw9vW0hjTJwRWx0bDXiSpYsO3gKogaPz") |> 
    as_tibble() |> 
    select(-individualId, -organizationName)
players
# Out:
# Rows: 196 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, age
# lgl (3): subscribe, individualId, organizationName
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# 25  Amateur     TRUE
# 26  Regular     TRUE
# 27  Regular     TRUE
# 28  Veteran    FALSE
# 29  Amateur     TRUE
# 30  Veteran    FALSE
# ⋮   ⋮          ⋮
# 167 Amateur    FALSE
# 168 Beginner   FALSE
# 169 Veteran     TRUE
# 170 Veteran    FALSE
# 171 Pro        FALSE
# 172 Beginner   FALSE
# 173 Veteran     TRUE
# 174 Regular    FALSE
# 175 Veteran     TRUE
# 176 Amateur     TRUE
# 177 Pro        FALSE
# 178 Veteran    FALSE
# 179 Amateur     TRUE
# 180 Veteran     TRUE
# 181 Amateur    FALSE
# 182 Amateur     TRUE
# 183 Pro        FALSE
# 184 Amateur     TRUE
# 185 Pro        FALSE
# 186 Regular    FALSE
# 187 Veteran     TRUE
# 188 Amateur     TRUE
# 189 Beginner    TRUE
# 190 Amateur    FALSE
# 191 Amateur     TRUE
# 192 Amateur     TRUE
# 193 Veteran    FALSE
# 194 Amateur    FALSE
# 195 Amateur    FALSE
# 196 Pro         TRUE
#     hashedEmail
# 1   f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d
# 2   f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9
# 3   b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28
# 4   23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5
# 5   7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e
# 6   f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977
# 7   8e594b8953193b26f498db95a508b03c6fe1c24bb5251d392c18a0da9a722807
# 8   1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd
# 9   8b71f4d66a38389b7528bb38ba6eb71157733df7d1740371852a797ae97d82d1
# 10  bbe2d83de678f519c4b3daa7265e683b4fe2d814077f9094afd11d8f217039ec
# 11  7a4686586d290c67179275c7c3dfb4ea02f4d317d9ee0e2cee98baa27877a875
# 12  4caa42e1b20511552434978171dcf7283fb6eb857eb871327e39bfc328002309
# 13  4bed6f49b672974f706aa7f020b4f29020326bf594520593557cd381a51559b8
# 14  3caa832978e0596779f4ee7c686c4592fb6de893925025d25bf26be9a8cd03f5
# 15  6f9acf8ea9956fe817895c78d10e1e25c11aba335a451e5b0322b073ee5008c4
# 16  2313a06afe47eacc28ff55adf6f072e7d12b0d12d7cbae29656f9029ec72bb53
# 17  9db37a1d381697f6c83e3b97b276e38bb9d9c811ba4596edb75d4dbfea6415b0
# 18  a175d4741dc84e6baf77901f6e8e0a06f54809a34e6b5211159bced346f7fb3e
# 19  ab1f44f93c3b828f55458971db393052d9711df3e0e7ff69540bfebfcec555ff
# 20  20ae3f8b5323674fe6e537bc91928841cfc2a00c1b36522fd25370bb6fa89d36
# 21  bc704ff2bc676dbf48ee41b9e11481c1387bf758ad318f2428f336e3fecc6660
# 22  200db0417ee70863c7e2a0f214c737476fb86de5869d0b907a077d726357e687
# 23  f9ac013b2f0bc2bd4928a6a0fc8a0aae8b5c4f2670cf9e18f547b7e72034c965
# 24  89c8e07d6a2aa102d9cd05086d51b2e41195c9c807dd976a06f4262ff36d0cca
# 25  119f01b9877fc5ea0073d05602a353b91c4b48e4cf02f42bb8d661b46a34b760
# 26  5baba1651a0b92788bc0d6dcdf00be64af1cf9f0015bbeed204ddabd1d872e83
# 27  50cec73a632e4be7b155c3df5165de28b2c5baf092abcb7f509f5645776a56c2
# 28  f8acd26a5e452b682b9f8b20108caef1ee2e745efe08e95806980bd2388a3fea
# 29  4b01bce3f141289709e8278b02ba5d2aaa7105d7ccb9c7deb37670a80e332774
# 30  951e54f7376e2b2f0915e9e3646c701af4a2fe839385b13f9e0084b08f8070bd
# ⋮   ⋮
# 167 7096b30972a32029244fc6171f21bc5996b51b8d75df7a94f003dead428988f9
# 168 42eafe96ed5c1684e3b5cc614d1b01a117173d3ec6898abcf1177d9822bd39f7
# 169 9ba67e127e4e70d909f6237644bb4674b17bc6ae5c9e735f88cfc50e22b499c6
# 170 4bfad3613c71ace05644bf210195d9fb0d3d9513753ad2f8a16d1a80699bb906
# 171 060aca80f8cfbf1c91553a72f4d5ec8034764b05ab59fe8e1cf0eee9a7b67967
# 172 80afc8e7137de6a232421e926c1e6e64ddeef1d8157c4439746bc00fcf91e8a7
# 173 af6b2350478c6bd6af97c91c7eed1d121b82676d1d519ef5b6cfa16dd451fe27
# 174 7b17513f11968feaf6b02977885c436dc2a4549489ca25ef03022f9fbae19d81
# 175 171d3c323c6430ffe0722c931f4cced5c48935f6804e0ff250964e4c41da55b1
# 176 55d24216db39c27e1f17cc43d3127cbf8ed76ada6d098202b53ded319855e2c1
# 177 e1e5b1d36ab7680b6927fd3cb619c2b5373167750f90f7a21bf67b5d9b0fd73f
# 178 a1e0438d568b9c05a93cadaf99969e4d44794d19dea31edd723cbc916f878c33
# 179 9955ab948064150d3686ef564389bdc6d6c60bc620a5ce3084b3dec4a7a006a7
# 180 6b1cdc07fcc1f7ea09509341fd245dd34fdba386f14a493e9107c18604baedc9
# 181 93efabc9f7de58f44c457bac715cf8f9f44cd88cc574fc02624cac194d2f0ea5
# 182 42382bb2af563e6979c5b84d288cbb49bb2ef90b1bcf196c2902da4ce20eb7f3
# 183 f7875ae87a61632030d5c4029ee8cf081be7047b2b4a9c04ab5a706f59786197
# 184 24d4892c2c3ce11d3e54c3bf31ee218901cac7a2f564911d67424c8fdf0874fe
# 185 d46bd29a2ed08e3500bd8729085ef4b6f0ca65baf4c756f88b6bedf7a18e0352
# 186 8e98b6db2053af0bc0e62cd55bcea5a08f23986dec3d02ca520ea039517e6744
# 187 ba24bebe588a34ac546f8559850c65bc90cd9d51b821581bd6e25cff437a1081
# 188 e3f0ad9aadd27f3d1d9197e58546d045018daa767675033d9af9a2b74e763739
# 189 8c9d043ebb3689e679a37bfed30ea96272bcd14689ed2d9fcd68a4ae0c1663bc
# 190 514ebbaa30f0d162127e065ab780892b7930cf8d75944d5eb09c91c02d6026c7
# 191 644fe4200c19a73768b3fa598afcbd0948f7557925b7f17166285da23af31cc6
# 192 b6e9e593b9ec51c5e335457341c324c34a2239531e1890b93ca52ac1dc76b08f
# 193 71453e425f07d10da4fa2b349c83e73ccdf0fb3312f778b35c5802c3292c87bd
# 194 d572f391d452b76ea2d7e5e53a3d38bfd7499c7399db299bd4fedb06a46ad5bb
# 195 f19e136ddde68f365afc860c725ccff54307dedd13968e896a9f890c40aea436
# 196 d9473710057f7d42f36570f0be83817a4eea614029ff90cf50d8889cdd729d11
#     played_hours name      gender            age
# 1   30.3         Morgan    Male               9
# 2    3.8         Christian Male              17
# 3    0.0         Blake     Male              17
# 4    0.7         Flora     Female            21
# 5    0.1         Kylie     Male              21
# 6    0.0         Adrian    Female            17
# 7    0.0         Luna      Female            19
# 8    0.0         Emerson   Male              21
# 9    0.1         Natalie   Male              17
# 10   0.0         Nyla      Female            22
# 11   1.6         Lane      Female            23
# 12   0.0         Daniela   Male              17
# 13   1.5         Sarah     Female            25
# 14   0.2         Thatcher  Male              22
# 15   0.0         Niamh     Non-binary        17
# 16   0.0         Quinlan   Male              22
# 17   0.0         Elodie    Female            17
# 18  48.4         Xander    Female            17
# 19   0.5         Marley    Male              17
# 20   0.6         Ryker     Male              19
# 21   0.3         Andy      Male               8
# 22   0.1         Anastasia Female            17
# 23   1.0         Leah      Male              17
# 24   0.0         Ren       Male              17
# 25   0.7         Hugo      Female            21
# 26   0.6         Kendall   Female            28
# 27   0.0         Iman      Male              17
# 28   0.0         Finn      Male              23
# 29   1.8         Luca      Male              23
# 30   0.1         Vivienne  Male              18
# ⋮   ⋮            ⋮         ⋮                 ⋮
# 167  1.0         Radwan    Male              26
# 168  0.3         Ariana    Female            17
# 169  0.1         Quinton   Male              17
# 170  0.1         Rocco     Male              17
# 171  0.4         Lyra      Male              21
# 172  1.8         Amelia    Male              32
# 173  0.0         Saif      Agender           20
# 174  0.0         Balthazar Male              50
# 175  0.0         Parker    Male              17
# 176  0.3         Joaquim   Male              17
# 177  0.0         Jesse     Non-binary        17
# 178  2.7         Jamie     Non-binary        21
# 179  0.4         Charlie   Two-Spirited      17
# 180  0.1         Finnian   Non-binary        17
# 181  2.1         Sebastián Male              24
# 182  0.8         Hunter    Female            22
# 183  0.2         Liam      Male              17
# 184 32.0         Sidney    Male              22
# 185  1.7         Asher     Male              17
# 186  0.1         Sam       Male              18
# 187  0.1         Gabriela  Female            44
# 188  0.0         Jasper    Male              17
# 189  0.0         Lina      Female            17
# 190  0.0         Orion     Male              17
# 191  0.0         Rhys      Male              20
# 192  0.0         Bailey    Female            17
# 193  0.3         Pascal    Male              22
# 194  0.0         Dylan     Prefer not to say 17
# 195  2.3         Harlow    Male              17
# 196  0.2         Ahmed     Other             91

# %%
players |> distinct(gender)
# Out:
#   gender
# 1 Male
# 2 Female
# 3 Non-binary
# 4 Prefer not to say
# 5 Agender
# 6 Two-Spirited
# 7 Other

# %%
num_players <- players |> 
 mutate(experience = as.factor(experience)) |>
 mutate(experience = fct_recode(experience, "1"="Beginner", "2"="Amateur" , "3"="Regular", "4"="Pro","5"="Veteran")) |>
 mutate(experience = as.integer(experience)) |> 
 mutate(gender = as.factor(gender)) |>
 mutate(gender = fct_recode(gender, "1"="Male", 
                                    "2"="Female" , 
                                    "3"="Non-binary", 
                                    "4"="Prefer not to say",
                                    "5"="Agender",
                                    "6"="Two-Spirited",
                                    "7"="Other")) |>
 mutate(gender = as.integer(gender)) |> 
 mutate(subscribe = as.factor(subscribe)) |>
 mutate(subscribe = fct_recode(subscribe, 
                               "1"="TRUE", 
                              "2"="FALSE")) |>
 mutate(subscribe = as.integer(subscribe)) 
num_players
# Out:
#     experience subscribe
# 1   3          2
# 2   5          2
# 3   5          1
# 4   1          2
# 5   4          2
# 6   1          2
# 7   4          2
# 8   1          1
# 9   1          2
# 10  5          2
# 11  5          2
# 12  3          2
# 13  2          2
# 14  1          2
# 15  5          2
# 16  1          1
# 17  2          2
# 18  1          2
# 19  1          2
# 20  4          2
# 21  4          2
# 22  1          1
# 23  2          2
# 24  2          2
# 25  1          2
# 26  4          2
# 27  4          2
# 28  5          1
# 29  1          2
# 30  5          1
# ⋮   ⋮          ⋮
# 167 1          1
# 168 2          1
# 169 5          2
# 170 5          1
# 171 3          1
# 172 2          1
# 173 5          2
# 174 4          1
# 175 5          2
# 176 1          2
# 177 3          1
# 178 5          1
# 179 1          2
# 180 5          2
# 181 1          1
# 182 1          2
# 183 3          1
# 184 1          2
# 185 3          1
# 186 4          1
# 187 5          2
# 188 1          2
# 189 2          2
# 190 1          1
# 191 1          2
# 192 1          2
# 193 5          1
# 194 1          1
# 195 1          1
# 196 3          2
#     hashedEmail
# 1   f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d
# 2   f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9
# 3   b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28
# 4   23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5
# 5   7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e
# 6   f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977
# 7   8e594b8953193b26f498db95a508b03c6fe1c24bb5251d392c18a0da9a722807
# 8   1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd
# 9   8b71f4d66a38389b7528bb38ba6eb71157733df7d1740371852a797ae97d82d1
# 10  bbe2d83de678f519c4b3daa7265e683b4fe2d814077f9094afd11d8f217039ec
# 11  7a4686586d290c67179275c7c3dfb4ea02f4d317d9ee0e2cee98baa27877a875
# 12  4caa42e1b20511552434978171dcf7283fb6eb857eb871327e39bfc328002309
# 13  4bed6f49b672974f706aa7f020b4f29020326bf594520593557cd381a51559b8
# 14  3caa832978e0596779f4ee7c686c4592fb6de893925025d25bf26be9a8cd03f5
# 15  6f9acf8ea9956fe817895c78d10e1e25c11aba335a451e5b0322b073ee5008c4
# 16  2313a06afe47eacc28ff55adf6f072e7d12b0d12d7cbae29656f9029ec72bb53
# 17  9db37a1d381697f6c83e3b97b276e38bb9d9c811ba4596edb75d4dbfea6415b0
# 18  a175d4741dc84e6baf77901f6e8e0a06f54809a34e6b5211159bced346f7fb3e
# 19  ab1f44f93c3b828f55458971db393052d9711df3e0e7ff69540bfebfcec555ff
# 20  20ae3f8b5323674fe6e537bc91928841cfc2a00c1b36522fd25370bb6fa89d36
# 21  bc704ff2bc676dbf48ee41b9e11481c1387bf758ad318f2428f336e3fecc6660
# 22  200db0417ee70863c7e2a0f214c737476fb86de5869d0b907a077d726357e687
# 23  f9ac013b2f0bc2bd4928a6a0fc8a0aae8b5c4f2670cf9e18f547b7e72034c965
# 24  89c8e07d6a2aa102d9cd05086d51b2e41195c9c807dd976a06f4262ff36d0cca
# 25  119f01b9877fc5ea0073d05602a353b91c4b48e4cf02f42bb8d661b46a34b760
# 26  5baba1651a0b92788bc0d6dcdf00be64af1cf9f0015bbeed204ddabd1d872e83
# 27  50cec73a632e4be7b155c3df5165de28b2c5baf092abcb7f509f5645776a56c2
# 28  f8acd26a5e452b682b9f8b20108caef1ee2e745efe08e95806980bd2388a3fea
# 29  4b01bce3f141289709e8278b02ba5d2aaa7105d7ccb9c7deb37670a80e332774
# 30  951e54f7376e2b2f0915e9e3646c701af4a2fe839385b13f9e0084b08f8070bd
# ⋮   ⋮
# 167 7096b30972a32029244fc6171f21bc5996b51b8d75df7a94f003dead428988f9
# 168 42eafe96ed5c1684e3b5cc614d1b01a117173d3ec6898abcf1177d9822bd39f7
# 169 9ba67e127e4e70d909f6237644bb4674b17bc6ae5c9e735f88cfc50e22b499c6
# 170 4bfad3613c71ace05644bf210195d9fb0d3d9513753ad2f8a16d1a80699bb906
# 171 060aca80f8cfbf1c91553a72f4d5ec8034764b05ab59fe8e1cf0eee9a7b67967
# 172 80afc8e7137de6a232421e926c1e6e64ddeef1d8157c4439746bc00fcf91e8a7
# 173 af6b2350478c6bd6af97c91c7eed1d121b82676d1d519ef5b6cfa16dd451fe27
# 174 7b17513f11968feaf6b02977885c436dc2a4549489ca25ef03022f9fbae19d81
# 175 171d3c323c6430ffe0722c931f4cced5c48935f6804e0ff250964e4c41da55b1
# 176 55d24216db39c27e1f17cc43d3127cbf8ed76ada6d098202b53ded319855e2c1
# 177 e1e5b1d36ab7680b6927fd3cb619c2b5373167750f90f7a21bf67b5d9b0fd73f
# 178 a1e0438d568b9c05a93cadaf99969e4d44794d19dea31edd723cbc916f878c33
# 179 9955ab948064150d3686ef564389bdc6d6c60bc620a5ce3084b3dec4a7a006a7
# 180 6b1cdc07fcc1f7ea09509341fd245dd34fdba386f14a493e9107c18604baedc9
# 181 93efabc9f7de58f44c457bac715cf8f9f44cd88cc574fc02624cac194d2f0ea5
# 182 42382bb2af563e6979c5b84d288cbb49bb2ef90b1bcf196c2902da4ce20eb7f3
# 183 f7875ae87a61632030d5c4029ee8cf081be7047b2b4a9c04ab5a706f59786197
# 184 24d4892c2c3ce11d3e54c3bf31ee218901cac7a2f564911d67424c8fdf0874fe
# 185 d46bd29a2ed08e3500bd8729085ef4b6f0ca65baf4c756f88b6bedf7a18e0352
# 186 8e98b6db2053af0bc0e62cd55bcea5a08f23986dec3d02ca520ea039517e6744
# 187 ba24bebe588a34ac546f8559850c65bc90cd9d51b821581bd6e25cff437a1081
# 188 e3f0ad9aadd27f3d1d9197e58546d045018daa767675033d9af9a2b74e763739
# 189 8c9d043ebb3689e679a37bfed30ea96272bcd14689ed2d9fcd68a4ae0c1663bc
# 190 514ebbaa30f0d162127e065ab780892b7930cf8d75944d5eb09c91c02d6026c7
# 191 644fe4200c19a73768b3fa598afcbd0948f7557925b7f17166285da23af31cc6
# 192 b6e9e593b9ec51c5e335457341c324c34a2239531e1890b93ca52ac1dc76b08f
# 193 71453e425f07d10da4fa2b349c83e73ccdf0fb3312f778b35c5802c3292c87bd
# 194 d572f391d452b76ea2d7e5e53a3d38bfd7499c7399db299bd4fedb06a46ad5bb
# 195 f19e136ddde68f365afc860c725ccff54307dedd13968e896a9f890c40aea436
# 196 d9473710057f7d42f36570f0be83817a4eea614029ff90cf50d8889cdd729d11
#     played_hours name      gender age
# 1   30.3         Morgan    3       9
# 2    3.8         Christian 3      17
# 3    0.0         Blake     3      17
# 4    0.7         Flora     2      21
# 5    0.1         Kylie     3      21
# 6    0.0         Adrian    2      17
# 7    0.0         Luna      2      19
# 8    0.0         Emerson   3      21
# 9    0.1         Natalie   3      17
# 10   0.0         Nyla      2      22
# 11   1.6         Lane      2      23
# 12   0.0         Daniela   3      17
# 13   1.5         Sarah     2      25
# 14   0.2         Thatcher  3      22
# 15   0.0         Niamh     4      17
# 16   0.0         Quinlan   3      22
# 17   0.0         Elodie    2      17
# 18  48.4         Xander    2      17
# 19   0.5         Marley    3      17
# 20   0.6         Ryker     3      19
# 21   0.3         Andy      3       8
# 22   0.1         Anastasia 2      17
# 23   1.0         Leah      3      17
# 24   0.0         Ren       3      17
# 25   0.7         Hugo      2      21
# 26   0.6         Kendall   2      28
# 27   0.0         Iman      3      17
# 28   0.0         Finn      3      23
# 29   1.8         Luca      3      23
# 30   0.1         Vivienne  3      18
# ⋮   ⋮            ⋮         ⋮      ⋮
# 167  1.0         Radwan    3      26
# 168  0.3         Ariana    2      17
# 169  0.1         Quinton   3      17
# 170  0.1         Rocco     3      17
# 171  0.4         Lyra      3      21
# 172  1.8         Amelia    3      32
# 173  0.0         Saif      1      20
# 174  0.0         Balthazar 3      50
# 175  0.0         Parker    3      17
# 176  0.3         Joaquim   3      17
# 177  0.0         Jesse     4      17
# 178  2.7         Jamie     4      21
# 179  0.4         Charlie   7      17
# 180  0.1         Finnian   4      17
# 181  2.1         Sebastián 3      24
# 182  0.8         Hunter    2      22
# 183  0.2         Liam      3      17
# 184 32.0         Sidney    3      22
# 185  1.7         Asher     3      17
# 186  0.1         Sam       3      18
# 187  0.1         Gabriela  2      44
# 188  0.0         Jasper    3      17
# 189  0.0         Lina      2      17
# 190  0.0         Orion     3      17
# 191  0.0         Rhys      3      20
# 192  0.0         Bailey    2      17
# 193  0.3         Pascal    3      22
# 194  0.0         Dylan     6      17
# 195  2.3         Harlow    3      17
# 196  0.2         Ahmed     5      91

# %%
# gender exploratoy plot
player_plot_gender <- ggplot(players, aes(x = gender, y = played_hours)) + 
    geom_bar(stat = "identity") + labs(x = "Gender", y = "Play Time (in hours)") + ggtitle("Play Time vs Subscription")
player_plot_gender
player_num_plot <- ggplot(players, aes(x = gender)) + 
    geom_bar() + 
    labs(x = "Gender", y = "Number of players", title = "Number of players vs. Subscription")
player_num_plot
# Out:
# plot without title
# plot without title

# %%
player_plot_experience <- ggplot(players, aes(x = subscribe, y = played_hours)) + 
    geom_bar(stat = "identity") + labs(x = "Subscription", y = "Play Time (in hours)") + ggtitle("Play Time vs Subscription")
player_plot_experience
player_exp_plot <- ggplot(players, aes(x = subscribe)) + 
    geom_bar() + 
    labs(x = "Subscription", y = "Number of players", title = "Number of players vs. Subscription")
player_exp_plot
# Out:
# plot without title
# plot without title

# %%
player_plot_experience <- ggplot(players, aes(x = experience, y = played_hours)) + 
    geom_bar(stat = "identity") + labs(x = "Experience Level", y = "Play Time (in hours)") + ggtitle("Play Time vs Experience Level")
player_plot_experience
players_experience_plot <- ggplot(players, aes(x = experience)) + 
    geom_bar()
players_experience_plot
# Out:
# plot without title
# plot without title

# %%
#making regression model
set.seed(2024)
gridvals <- tibble(neighbors = seq(from = 1, to = 10, by = 1))


players_split <- initial_split(num_players, prop = 0.70, strata = played_hours)

training_players <- training(players_split)

testing_players <- testing(players_split)

players_recipe <- recipe(played_hours ~ experience + age + gender + subscribe, data = training_players) |> 
    step_scale(all_predictors()) |> 
    step_center(all_predictors()) 

players_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
    set_engine("kknn") |> 
    set_mode("regression")

vfold <- training_players |> 
    vfold_cv(v = 5, strata = played_hours)

players_test_workflow <- workflow() |> 
    add_recipe(players_recipe) |> 
    add_model(players_spec_tune) |> 
    tune_grid(resamples = vfold, grid = gridvals) |> 
    collect_metrics()

players_min <- players_test_workflow |> 
    filter(.metric == "rmse") |> 
    slice_min(mean, n = 1)
players_min
#use K = 10
# Out:
#   neighbors .metric .estimator mean     n std_err  .config
# 1 10        rmse    standard   22.26946 5 8.459121 Preprocessor1_Model10

# %%
set.seed(2024)
k_min <- players_min |> 
    pull(neighbors)
players_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min) |> 
    set_engine("kknn") |> 
    set_mode("regression")
players_workflow <- workflow() |> 
    add_recipe(players_recipe) |> 
    add_model(players_spec) |> 
    fit(data = training_players)
players_summary <- players_workflow |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_summary
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   35.18920819
# 2 rsq     standard    0.01021185
# 3 mae     standard   10.45033333

# %%
 #try linear regression
set.seed(2024)
lm_spec <- linear_reg() |> 
    set_engine("lm") |> 
    set_mode("regression")
players_linear_fit <- workflow() |> 
    add_recipe(players_recipe) |> 
    add_model(lm_spec) |> 
    fit(data = training_players)
players_preds <- players_linear_fit |> 
    predict(training_players) |> 
    bind_cols(training_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_preds
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   25.10855982
# 2 rsq     standard    0.01733424
# 3 mae     standard    8.81464534

# %%
set.seed(2024)
players_pred_test <- players_linear_fit |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_pred_test
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   33.88337727
# 2 rsq     standard    0.01253101
# 3 mae     standard   11.63101839

# %%
# attempts of different groupings of predictors to see if there are better rmse values -- for KNN regression ( experience + age ) 

#Commit: Added different predictor combos for K-NN I copied + pasted the K-NN classifier code and modified it to account for different predictor combinations. Not much improvement was made

set.seed(2024)
gridvals <- tibble(neighbors = seq(from = 1, to = 10, by = 1))


players_split <- initial_split(num_players, prop = 0.70, strata = played_hours)

training_players <- training(players_split)

testing_players <- testing(players_split)

# Modifying the recipe to include only experience and age
players_recipe_exp_age <- recipe(played_hours ~ experience + age, data = training_players) |> 
    step_scale(all_predictors()) |> 
    step_center(all_predictors())

players_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
    set_engine("kknn") |> 
    set_mode("regression")

vfold <- training_players |> 
    vfold_cv(v = 5, strata = played_hours)

players_test_workflow_exp_age <- workflow() |> 
    add_recipe(players_recipe_exp_age) |> 
    add_model(players_spec_tune) |> 
    tune_grid(resamples = vfold, grid = gridvals) |> 
    collect_metrics()

players_min_exp_age <- players_test_workflow_exp_age |> 
    filter(.metric == "rmse") |> 
    slice_min(mean, n = 1)
players_min_exp_age
#use K = 1

k_min_exp_age <- players_min_exp_age |> 
    pull(neighbors)

players_spec_exp_age <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min_exp_age) |> 
    set_engine("kknn") |> 
    set_mode("regression")

players_workflow_exp_age <- workflow() |> 
    add_recipe(players_recipe_exp_age) |> 
    add_model(players_spec_exp_age) |> 
    fit(data = training_players)

# evaluate on testing set
players_summary_exp_age <- players_workflow_exp_age |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_summary_exp_age


# Not amazing but better - Better rsme ( went from 35 to 34.8 ),  rsq - ( went from 0.01021185 to 0.006605382), 
# mae dropped from 10.45033333 to 7.7 ish! 
# Could be because subscriber + gender weren't good predictors
# Out:
#   neighbors .metric .estimator mean     n std_err .config
# 1 1         rmse    standard   17.88375 5 9.87936 Preprocessor1_Model01
#   .metric .estimator .estimate
# 1 rmse    standard   34.814412724
# 2 rsq     standard    0.006605382
# 3 mae     standard    7.703333333

# %%
# attempts of different groupings of predictors to see if there are better rmse values -- for KNN regression ( subscribe + age ) 



set.seed(2024)
gridvals <- tibble(neighbors = seq(from = 1, to = 10, by = 1))


players_split <- initial_split(num_players, prop = 0.70, strata = played_hours)

training_players <- training(players_split)

testing_players <- testing(players_split)

# Modifying the recipe to include only experience and age
players_recipe_sub_age <- recipe(played_hours ~ subscribe + age, data = training_players) |> 
    step_scale(all_predictors()) |> 
    step_center(all_predictors())

players_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
    set_engine("kknn") |> 
    set_mode("regression")

vfold <- training_players |> 
    vfold_cv(v = 5, strata = played_hours)

players_test_workflow_sub_age <- workflow() |> 
    add_recipe(players_recipe_sub_age) |> 
    add_model(players_spec_tune) |> 
    tune_grid(resamples = vfold, grid = gridvals) |> 
    collect_metrics()

players_min_sub_age <- players_test_workflow_sub_age |> 
    filter(.metric == "rmse") |> 
    slice_min(mean, n = 1)
players_min_sub_age
#use K = 10

k_min_sub_age <- players_min_sub_age |> 
    pull(neighbors)

players_spec_sub_age <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min_sub_age) |> 
    set_engine("kknn") |> 
    set_mode("regression")

players_workflow_sub_age <- workflow() |> 
    add_recipe(players_recipe_sub_age) |> 
    add_model(players_spec_sub_age) |> 
    fit(data = training_players)

# evaluate on testing set
players_summary_sub_age <- players_workflow_sub_age |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_summary_sub_age

# not amazing differences from previous
# Out:
#   neighbors .metric .estimator mean     n std_err  .config
# 1 10        rmse    standard   17.81739 5 9.727763 Preprocessor1_Model10
#   .metric .estimator .estimate
# 1 rmse    standard   34.962688136
# 2 rsq     standard    0.007748419
# 3 mae     standard    8.834166667

# %%
# attempts of different groupings of predictors to see if there are better rmse values -- for KNN regression ( experience + subscribe + age ) 



set.seed(2024)
gridvals <- tibble(neighbors = seq(from = 1, to = 100, by = 1))


players_split <- initial_split(num_players, prop = 0.70, strata = played_hours)

training_players <- training(players_split)

testing_players <- testing(players_split)

# Modifying the recipe to include only experience and age
players_recipe_sub_age_exp <- recipe(played_hours ~ subscribe + age + experience, data = training_players) |> 
    step_scale(all_predictors()) |> 
    step_center(all_predictors())

players_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
    set_engine("kknn") |> 
    set_mode("regression")

vfold <- training_players |> 
    vfold_cv(v = 5, strata = played_hours)

players_test_workflow_sub_age_exp <- workflow() |> 
    add_recipe(players_recipe_sub_age_exp) |> 
    add_model(players_spec_tune) |> 
    tune_grid(resamples = vfold, grid = gridvals) |> 
    collect_metrics()

players_min_sub_age_exp <- players_test_workflow_sub_age_exp |> 
    filter(.metric == "rmse") |> 
    slice_min(mean, n = 1)
players_min_sub_age_exp
#use K = 1

k_min_sub_age_exp <- players_min_sub_age_exp |> 
    pull(neighbors)

players_spec_sub_age_exp <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min_sub_age_exp) |> 
    set_engine("kknn") |> 
    set_mode("regression")

players_workflow_sub_age_exp <- workflow() |> 
    add_recipe(players_recipe_sub_age_exp) |> 
    add_model(players_spec_sub_age_exp) |> 
    fit(data = training_players)

# evaluate on testing set
players_summary_sub_age_exp <- players_workflow_sub_age_exp |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_summary_sub_age_exp

# again, not amazing differences from previous -- almost exactly the same besides rsq
# Out:
#   neighbors .metric .estimator mean    n std_err  .config
# 1 1         rmse    standard   17.8194 5 9.843304 Preprocessor1_Model001
#   .metric .estimator .estimate
# 1 rmse    standard   34.987088095
# 2 rsq     standard    0.003326762
# 3 mae     standard    8.426666667

# %%
players_subset <- num_players |>
  select(played_hours, experience, subscribe, gender, age)

names <- colnames(players_subset |> select(-played_hours))

# Create an empty tibble to store the results
accuracies <- tibble(size = integer(),
                     model_string = character(),
                     metric = numeric())

# Create a model specification
knn_spec <- nearest_neighbor(weight_func = "rectangular",
                             neighbors = tune()) |>
     set_engine("kknn") |>
     set_mode("regression")

# Create a 5-fold cross-validation object
players_vfold <- vfold_cv(players_subset, v = 5, strata = played_hours)

# Store the total number of predictors
n_total <- length(names)

# Stores selected predictors
selected <- c()

# For every size from 1 to the total number of predictors
for (i in 1:n_total) {
    accs <- list()
    models <- list()
    for (j in 1:length(names)) {
        # Create a model string for this combination of predictors
        preds_new <- c(selected, names[[j]])
        model_string <- paste("played_hours", "~", paste(preds_new, collapse = "+"))

        # Create a recipe from the model string
        played_recipe <- recipe(as.formula(model_string),
                                data = players_subset) |>
                          step_scale(all_predictors()) |>
                          step_center(all_predictors())

        # Tune the K-NN regressor with these predictors
        res <- workflow() |>
          add_recipe(played_recipe) |>
          add_model(knn_spec) |>
          tune_grid(resamples = players_vfold, grid = 10) |>
          collect_metrics() |>
          filter(.metric == "rmse") # Use RMSE for regression

        # Collect the minimum RMSE value
        acc <- res |> summarize(mx = min(mean)) |> pull(mx)

        # Add this result to the lists
        accs[[j]] <- acc
        models[[j]] <- model_string
    }

    # Select the best model from this round
    jstar <- which.min(unlist(accs))
    accuracies <- accuracies |>
      add_row(size = i,
              model_string = models[[jstar]],
              metric = accs[[jstar]])
    selected <- c(selected, names[[jstar]])
    names <- names[-jstar]
}

accuracies
# Out:
#   size model_string                                   metric
# 1 1    played_hours ~ subscribe                       26.91019
# 2 2    played_hours ~ subscribe+experience            26.56804
# 3 3    played_hours ~ subscribe+experience+gender     27.53094
# 4 4    played_hours ~ subscribe+experience+gender+age 28.42212

# %%
gridvals <- tibble(neighbors = seq(from = 1, to = 100, by = 1))

players_split <- initial_split(num_players, prop = 0.70, strata = played_hours)

training_players <- training(players_split)

testing_players <- testing(players_split)

# Modifying the recipe to include only experience and age
players_recipe <- recipe(played_hours ~ subscribe +experience, data = training_players) |> 
    step_scale(all_predictors()) |> 
    step_center(all_predictors())

players_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
    set_engine("kknn") |> 
    set_mode("regression")

vfold <- training_players |> 
    vfold_cv(v = 5, strata = played_hours)

players_workflow <- workflow() |> 
    add_recipe(players_recipe) |> 
    add_model(players_spec_tune) |> 
    tune_grid(resamples = vfold, grid = gridvals) |> 
    collect_metrics()

players_min <- players_workflow |> 
    filter(.metric == "rmse") |> 
    slice_min(mean, n = 1)
players_min_sub_age_exp
#use K = 10

k_min <- players_min |> 
    pull(neighbors)

players_spec_final <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min) |> 
    set_engine("kknn") |> 
    set_mode("regression")

players_workflow_final <- workflow() |> 
    add_recipe(players_recipe_sub_age_exp) |> 
    add_model(players_spec_sub_age_exp) |> 
    fit(data = training_players)

# evaluate on testing set
players_summary_final <- players_workflow_final |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_summary_final
# Out:
# → A | warning: A correlation computation is required, but `estimate` is constant and has 0
#                standard deviation, resulting in a divide by 0 error. `NA` will be returned.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
#   neighbors .metric .estimator mean    n std_err  .config
# 1 1         rmse    standard   17.8194 5 9.843304 Preprocessor1_Model001
#   .metric .estimator .estimate
# 1 rmse    standard   42.041223817
# 2 rsq     standard    0.003887417
# 3 mae     standard   11.781666667

# %%
gridvals <- tibble(neighbors = seq(from = 1, to = 100, by = 1))

players_split <- initial_split(num_players, prop = 0.70, strata = played_hours)

training_players <- training(players_split)

testing_players <- testing(players_split)

# Modifying the recipe to include only experience and age
players_recipe <- recipe(played_hours ~experience, data = training_players) |> 
    step_scale(all_predictors()) |> 
    step_center(all_predictors())

players_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
    set_engine("kknn") |> 
    set_mode("regression")

vfold <- training_players |> 
    vfold_cv(v = 5, strata = played_hours)

players_workflow <- workflow() |> 
    add_recipe(players_recipe) |> 
    add_model(players_spec_tune) |> 
    tune_grid(resamples = vfold, grid = gridvals) |> 
    collect_metrics()

players_min <- players_workflow |> 
    filter(.metric == "rmse") |> 
    slice_min(mean, n = 1)
players_min_sub_age_exp
#use K = 10

k_min <- players_min |> 
    pull(neighbors)

players_spec_final <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min) |> 
    set_engine("kknn") |> 
    set_mode("regression")

players_workflow_final <- workflow() |> 
    add_recipe(players_recipe) |> 
    add_model(players_spec_final) |> 
    fit(data = training_players)

# evaluate on testing set
players_summary_final <- players_workflow_final |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_summary_final


experience_prediction_grid <- tibble(
  experience = seq(from = 1, to = 7, by = 1))  # Experience from 1 to 7
players_preds <- players_workflow_final |>
  predict(experience_prediction_grid) |>
  bind_cols(experience_prediction_grid)

plot_final <- ggplot(num_players, aes(x = experience, y = played_hours)) +
  geom_point(alpha = 0.4) +
  geom_line(data = players_preds,
            mapping = aes(x = experience, y = .pred),
            color = "steelblue",
            linewidth = 1) +
  xlab("Player experience") +
  ylab("Played hours") +
  ggtitle(paste0("K = ", k_min)) +
  theme(text = element_text(size = 12))

plot_final
# Out:
# → A | warning: A correlation computation is required, but `estimate` is constant and has 0
#                standard deviation, resulting in a divide by 0 error. `NA` will be returned.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x1
#   neighbors .metric .estimator mean    n std_err  .config
# 1 1         rmse    standard   17.8194 5 9.843304 Preprocessor1_Model001
#   .metric .estimator .estimate
# 1 rmse    standard   2.531099e+01
# 2 rsq     standard   5.575009e-08
# 3 mae     standard   5.649000e+00
# plot without title

# %%
gridvals <- tibble(neighbors = seq(from = 1, to = 100, by = 1))

players_split <- initial_split(num_players, prop = 0.70, strata = played_hours)

training_players <- training(players_split)

testing_players <- testing(players_split)

# Modifying the recipe to include only experience and age
players_recipe_subs <- recipe(played_hours ~subscribe, data = training_players) |> 
    step_scale(all_predictors()) |> 
    step_center(all_predictors())

players_spec_tune_subs <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |> 
    set_engine("kknn") |> 
    set_mode("regression")

vfold <- training_players |> 
    vfold_cv(v = 5, strata = played_hours)

players_workflow_subs <- workflow() |> 
    add_recipe(players_recipe_subs) |> 
    add_model(players_spec_tune_subs) |> 
    tune_grid(resamples = vfold, grid = gridvals) |> 
    collect_metrics()

players_min_subs <- players_workflow_subs |> 
    filter(.metric == "rmse") |> 
    slice_min(mean, n = 1)
players_min_subs
#use K = 10

k_min <- players_min_subs |> 
    pull(neighbors)

players_spec_final_subs <- nearest_neighbor(weight_func = "rectangular", neighbors = k_min) |> 
    set_engine("kknn") |> 
    set_mode("regression")

players_workflow_final_subs <- workflow() |> 
    add_recipe(players_recipe_subs) |> 
    add_model(players_spec_final_subs) |> 
    fit(data = training_players)

# evaluate on testing set
players_summary_final_subs <- players_workflow_final_subs |> 
    predict(testing_players) |> 
    bind_cols(testing_players) |> 
    metrics(truth = played_hours, estimate = .pred)
players_summary_final_subs


experience_prediction_grid <- tibble(
  subscribe = c(1,2))  
players_preds <- players_workflow_final_subs |>
  predict(experience_prediction_grid) |>
  bind_cols(experience_prediction_grid)

plot_final <- ggplot(num_players, aes(x = subscribe, y = played_hours)) +
  geom_point(alpha = 0.4) +
  geom_line(data = players_preds,
            mapping = aes(x = subscribe, y = .pred),
            color = "steelblue",
            linewidth = 1) +
  xlab("Player subscribe") +
  ylab("Played hours") +
  ggtitle(paste0("K = ", k_min)) +
  theme(text = element_text(size = 12))

plot_final
# Out:
# → A | warning: A correlation computation is required, but `estimate` is constant and has 0
#                standard deviation, resulting in a divide by 0 error. `NA` will be returned.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x2
#
# There were issues with some computations   A: x5
#   neighbors .metric .estimator mean     n std_err .config
# 1 46        rmse    standard   25.79137 5 8.29347 Preprocessor1_Model046
#   .metric .estimator .estimate
# 1 rmse    standard   24.98715310
# 2 rsq     standard    0.02221721
# 3 mae     standard    6.01398551
# plot without title
